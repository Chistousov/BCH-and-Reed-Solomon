# %% [markdown]
# $$
# \text{Конечное поле (поле Галуа) }GF(2 ^ 6)
# \text{, которое опишем через } \mathbb{F}_2[x]/(x^6+x^4+x^3+x+1) \text{ по изоморфизму, где } x^6+x^4+x^3+x+1 \text{-неприводимый полином над }\mathbb{F}_2[x]
# $$

# %% [markdown]
# $$
# \def\arraystretch{1.5}
#    \begin{array}{c:c:c}
#    a & b & c \\ \hline
#    d & e & f \\
#    \hdashline
#    g & h & i
# \end{array}
# $$

# %% [markdown]
# $$
# \begin{array}{c:c:c}
#
# \text{Элемент поля }GF(2 ^ 6)
# &
# \text{Элемент поля }\mathbb{F}_2[x]/(x^6+x^4+x^3+x+1)
# &
# \text{Битовое представление} \\
# \\ \hline \\
#
# \alpha ^ \infty
# &
# 0
# &
# 000000 \\
# \\ \hline \\
#
# \alpha ^ 0
# &
# 1
# &
# 000001 \\
# \\ \hline \\
#
# \alpha
# &
# x
# &
# 000010 \\
# \\ \hline \\
#
# \alpha ^ 2
# &
# x ^ 2
# &
# 000100 \\
# \\ \hline \\
#
# \alpha ^ 3
# &
# x ^ 3
# &
# 001000 \\
# \\ \hline \\
#
# \alpha ^ 4
# &
# x ^ 4
# &
# 010000 \\
# \\ \hline \\
#
# \alpha ^ 5
# &
# x ^ 5
# &
# 100000 \\
# \\ \hline \\
#
# \alpha ^ 6 = \alpha ^ 4 + \alpha ^ 3 + \alpha + 1
# &
# x ^ 4 + x ^ 3 + x + 1
# &
# 011011 \\
# \\ \hline \\
#
# \alpha ^ 7 = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 2 + \alpha
# &
# x ^ 5 + x ^ 4 + x ^ 2 + x
# &
# 110110 \\
# \\ \hline \\
#
#
# \alpha ^ 8 = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 5 + x ^ 4 + x ^ 2 + x + 1
# &
# 110111 \\
# \\ \hline \\
#
# \alpha ^ 9 = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 2 + 1
# &
# x ^ 5 + x ^ 4 + x ^ 2 + 1
# &
# 110101 \\
# \\ \hline \\
#
# \alpha ^ {10} = \alpha ^ 5 + \alpha ^ 4 + 1
# &
# x ^ 5 + x ^ 4 + 1
# &
# 110001 \\
# \\ \hline \\
#
# \alpha ^ {11} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + 1
# &
# x ^ 5 + x ^ 4 + x ^ 3 + 1
# &
# 111001 \\
# \\ \hline \\
#
# \alpha ^ {12} = \alpha ^ 5 + \alpha ^ 3 + 1
# &
# x ^ 5 + x ^ 3 + 1
# &
# 101001 \\
# \\ \hline \\
#
# \alpha ^ {13} = \alpha ^ 3 + 1
# &
# x ^ 3 + 1
# &
# 001001 \\
# \\ \hline \\
#
# \alpha ^ {14} = \alpha ^ 4 + \alpha
# &
# x ^ 4 + x
# &
# 010010 \\
# \\ \hline \\
#
# \alpha ^ {15} = \alpha ^ 5 + \alpha ^ 2
# &
# x ^ 5 + x ^ 2
# &
# 100100 \\
# \\ \hline \\
#
# \alpha ^ {16} = \alpha ^ 4 + \alpha + 1
# &
# x ^ 4 + x + 1
# &
# 010011 \\
# \\ \hline \\
#
# \alpha ^ {17} = \alpha ^ 5 + \alpha ^ 2 + \alpha
# &
# x ^ 5 + x ^ 2 + x
# &
# 100110 \\
# \\ \hline \\
#
# \alpha ^ {18} = \alpha ^ 4 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 4 + x ^ 2 + x + 1
# &
# 010111 \\
# \\ \hline \\
#
# \alpha ^ {19} = \alpha ^ 5 + \alpha ^ 3 + \alpha ^ 2 + \alpha
# &
# x ^ 5 + x ^ 3 + x ^ 2 + x
# &
# 101110 \\
# \\ \hline \\
#
# \alpha ^ {20} = \alpha ^ 2 + \alpha + 1
# &
# x ^ 2 + x + 1
# &
# 000111 \\
# \\ \hline \\
#
# \alpha ^ {21} = \alpha ^ 3 + \alpha ^ 2 + \alpha
# &
# x ^ 3 + x ^ 2 + x
# &
# 001110 \\
# \\ \hline \\
#
# \alpha ^ {22} = \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2
# &
# x ^ 4 + x ^ 3 + x ^ 2
# &
# 011100 \\
# \\ \hline \\
#
# \alpha ^ {23} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3
# &
# x ^ 5 + x ^ 4 + x ^ 3
# &
# 111000 \\
# \\ \hline \\
#
# \alpha ^ {24} = \alpha ^ 5 + \alpha ^ 3 + \alpha + 1
# &
# x ^ 5 + x ^ 3 + x + 1
# &
# 101011 \\
# \\ \hline \\
#
# \alpha ^ {25} = \alpha ^ 3 + \alpha ^ 2 + 1
# &
# x ^ 3 + x ^ 2 + 1
# &
# 001101 \\
# \\ \hline \\
#
# \alpha ^ {26} = \alpha ^ 4 + \alpha ^ 3 + \alpha
# &
# x ^ 4 + x ^ 3 + x
# &
# 011010 \\
# \\ \hline \\
#
# \alpha ^ {27} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 2
# &
# x ^ 5 + x ^ 4 + x ^ 2
# &
# 110100 \\
# \\ \hline \\
#
# \alpha ^ {28} = \alpha ^ 5 + \alpha ^ 4 + \alpha + 1
# &
# x ^ 5 + x ^ 4 + x + 1
# &
# 110011 \\
# \\ \hline \\
#
# \alpha ^ {29} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + 1
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x ^ 2 + 1
# &
# 111101 \\
# \\ \hline \\
#
# \alpha ^ {30} = \alpha ^ 5 + 1
# &
# x ^ 5 + 1
# &
# 100001 \\
# \\ \hline \\
#
# \alpha ^ {31} = \alpha ^ 4 + \alpha ^ 3 + 1
# &
# x ^ 4 + x ^ 3 + 1
# &
# 011001 \\
# \\ \hline \\
#
# \alpha ^ {32} = \alpha ^ 5 + \alpha ^ 4 + \alpha
# &
# x ^ 5 + x ^ 4 + x
# &
# 110010 \\
# \\ \hline \\
#
# \alpha ^ {33} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x ^ 2 + x + 1
# &
# 111111 \\
# \\ \hline \\
#
# \alpha ^ {34} = \alpha ^ 5 + \alpha ^ 2 + 1
# &
# x ^ 5 + x ^ 2 + 1
# &
# 100101 \\
# \\ \hline \\
#
# \alpha ^ {35} = \alpha ^ 4 + 1
# &
# x ^ 4 + 1
# &
# 010001 \\
# \\ \hline \\
#
# \alpha ^ {36} = \alpha ^ 5 + \alpha
# &
# x ^ 5 + x
# &
# 100010 \\
# \\ \hline \\
#
# \alpha ^ {37} = \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 4 + x ^ 3 + x ^ 2 + x + 1
# &
# 011111 \\
# \\ \hline \\
#
# \alpha ^ {38} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + \alpha
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x ^ 2 + x
# &
# 111110 \\
# \\ \hline \\
#
# \alpha ^ {39} = \alpha ^ 5 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 5 + x ^ 2 + x + 1
# &
# 100111 \\
# \\ \hline \\
#
# \alpha ^ {40} = \alpha ^ 4 + \alpha ^ 2 + 1
# &
# x ^ 4 + x ^ 2 + 1
# &
# 010101 \\
# \\ \hline \\
#
# \alpha ^ {41} = \alpha ^ 5 + \alpha ^ 3 + \alpha
# &
# x ^ 5 + x ^ 3 + x
# &
# 101010 \\
# \\ \hline \\
#
# \alpha ^ {42} = \alpha ^ 3 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 3 + x ^ 2 + x + 1
# &
# 001111 \\
# \\ \hline \\
#
# \alpha ^ {43} = \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + \alpha
# &
# x ^ 4 + x ^ 3 + x ^ 2 + x
# &
# 011110 \\
# \\ \hline \\
#
# \alpha ^ {44} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x ^ 2
# &
# 111100 \\
# \\ \hline \\
#
# \alpha ^ {45} = \alpha ^ 5 + \alpha + 1
# &
# x ^ 5 + x + 1
# &
# 100011 \\
# \\ \hline \\
#
# \alpha ^ {46} = \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + 1
# &
# x ^ 4 + x ^ 3 + x ^ 2 + 1
# &
# 011101 \\
# \\ \hline \\
#
# \alpha ^ {47} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x
# &
# 111010 \\
# \\ \hline \\
#
# \alpha ^ {48} = \alpha ^ 5 + \alpha ^ 3 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 5 + x ^ 3 + x ^ 2 + x + 1
# &
# 101111 \\
# \\ \hline \\
#
# \alpha ^ {49} = \alpha ^ 2 + 1
# &
# x ^ 2 + 1
# &
# 000101 \\
# \\ \hline \\
#
# \alpha ^ {50} = \alpha ^ 3 + \alpha
# &
# x ^ 3 + x
# &
# 001010 \\
# \\ \hline \\
#
# \alpha ^ {51} = \alpha ^ 4 + \alpha ^ 2
# &
# x ^ 4 + x ^ 2
# &
# 010100 \\
# \\ \hline \\
#
# \alpha ^ {52} = \alpha ^ 5 + \alpha ^ 3
# &
# x ^ 5 + x ^ 3
# &
# 101000 \\
# \\ \hline \\
#
# \alpha ^ {53} = \alpha ^ 3 + \alpha + 1
# &
# x ^ 3 + x + 1
# &
# 001011 \\
# \\ \hline \\
#
# \alpha ^ {54} = \alpha ^ 4 + \alpha ^ 2 + \alpha
# &
# x ^ 4 + x ^ 2 + x
# &
# 010110 \\
# \\ \hline \\
#
# \alpha ^ {55} = \alpha ^ 5 + \alpha ^ 3 + \alpha ^ 2
# &
# x ^ 5 + x ^ 3 + x ^ 2
# &
# 101100 \\
# \\ \hline \\
#
# \alpha ^ {56} = \alpha + 1
# &
# x + 1
# &
# 000011 \\
# \\ \hline \\
#
# \alpha ^ {57} = \alpha ^ 2 + \alpha
# &
# x ^ 2 + x
# &
# 000110 \\
# \\ \hline \\
#
# \alpha ^ {58} = \alpha ^ 3 + \alpha ^ 2
# &
# x ^ 3 + x ^ 2
# &
# 001100 \\
# \\ \hline \\
#
# \alpha ^ {59} = \alpha ^ 4 + \alpha ^ 3
# &
# x ^ 4 + x ^ 3
# &
# 011000 \\
# \\ \hline \\
#
# \alpha ^ {60} = \alpha ^ 5 + \alpha ^ 4
# &
# x ^ 5 + x ^ 4
# &
# 110000 \\
# \\ \hline \\
#
# \alpha ^ {61} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha + 1
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x + 1
# &
# 111011 \\
# \\ \hline \\
#
# \alpha ^ {62} = \alpha ^ 5 + \alpha ^ 3 + \alpha ^ 2 + 1
# &
# x ^ 5 + x ^ 3 + x ^ 2 + 1
# &
# 101101 \\
# \\ \hline \\
#
# \end {array}
# $$

# %% [markdown]
# Минимальные многочлены
#
# \begin{array}{c:c}
#
# \text{Минимальный многочлен поля }GF(2 ^ 6) \text{ как многочлен над полем }\mathbb{F}_2[x]
# &
# \text{корни} \\
# \\ \hline \\
#
# m_0(x) = x + 1
# &
# 1 \\
# \\ \hline \\
#
# m_1(x) = x ^ 6 + x ^ 4 + x ^ 3 + x + 1
# &
# \alpha, \alpha ^ {2}, \alpha ^ {4}, \alpha ^ {8}, \alpha ^ {16}, \alpha ^ {32} \\
# \\ \hline \\
#
# m_2(x) = x ^ 6 + x ^ 5 + x ^ 4 + x ^ 2 + 1
# &
# \alpha ^ {3}, \alpha ^ {6}, \alpha ^ {12}, \alpha ^ {24}, \alpha ^ {48}, \alpha ^ {33} \\
# \\ \hline \\
#
# m_3(x) = x ^ 6 + x + 1
# &
# \alpha ^ {5}, \alpha ^ {10}, \alpha ^ {20}, \alpha ^ {40}, \alpha ^ {17}, \alpha ^ {34} \\
# \\ \hline \\
#
# m_4(x) = x ^ 6 + x ^ 3 + 1
# &
# \alpha ^ {7}, \alpha ^ {14}, \alpha ^ {28}, \alpha ^ {56}, \alpha ^ {49}, \alpha ^ {35}  \\
# \\ \hline \\
#
# m_5(x) = x ^ 3 + x + 1
# &
# \alpha ^ {9}, \alpha ^ {18}, \alpha ^ {36}  \\
# \\ \hline \\
#
# m_6(x) = x ^ 6 + x ^ 5 + x ^ 2 + x + 1
# &
# \alpha ^ {11}, \alpha ^ {22}, \alpha ^ {44}, \alpha ^ {25}, \alpha ^ {50}, \alpha ^ {37}  \\
# \\ \hline \\
#
# m_7(x) = x ^ 6 + x ^ 5 + x ^ 4 + x + 1
# &
# \alpha ^ {13}, \alpha ^ {26}, \alpha ^ {52}, \alpha ^ {41}, \alpha ^ {19}, \alpha ^ {38} \\
# \\ \hline \\
#
# m_8(x) = x ^ 6 + x ^ 4 + x ^ 2 + x + 1
# &
# \alpha ^ {15}, \alpha ^ {30}, \alpha ^ {60}, \alpha ^ {57}, \alpha ^ {51}, \alpha ^ {39}  \\
# \\ \hline \\
#
# m_9(x) = x ^ 2 + x + 1
# &
# \alpha ^ {21}, \alpha ^ {42}  \\
# \\ \hline \\
#
# m_{10}(x) = x ^ 6 + x ^ 5 + 1
# &
# \alpha ^ {23}, \alpha ^ {46}, \alpha ^ {29}, \alpha ^ {58}, \alpha ^ {53}, \alpha ^ {43} \\
# \\ \hline \\
#
# m_{11}(x) = x ^ 3 + x ^ 2 + 1
# &
# \alpha ^ {27}, \alpha ^ {54}, \alpha ^ {45} \\
# \\ \hline \\
#
# m_{12}(x) = x ^ 6 + x ^ 5 + x ^ 3 + x ^ 2 + 1
# &
# \alpha ^ {31}, \alpha ^ {62}, \alpha ^ {61}, \alpha ^ {59}, \alpha ^ {55}, \alpha ^ {47} \\
# \\ \hline \\
#
#
# \end {array}

# %% [markdown]
# $$\text{Пример кода БЧХ}$$

# %% [markdown]
# $$\alpha ^ {b}, \alpha ^ {b + 1}, ..., \alpha ^ {b + d - 2}; d = 2t + 1; GF(2 ^ 6) \implies q = 2, m = 6; b = 1, t = 2 \implies d = 2 \cdot 2 + 1 = 5 \implies b + d - 2 = 1 + 5 - 2 = 4 \implies \alpha, \alpha ^ 2, ..., \alpha ^ 4 \implies $$
# $$ g(x) = (x ^ 6 + x ^ 4 + x ^ 3 + x + 1) \cdot (x ^ 6 + x ^ 5 + x ^ 4 + x ^ 2 + 1) = x ^ {12} + x ^ {11} + x ^ 8 + x ^ 5 + x ^ 2 + x + 1;$$
# $$ n = q ^ m - 1 = 2 ^ 6 - 1 = 63, r = \deg(g(x)) = n - k = 12 \implies k = 63 - 12 = 51 \implies (63,51) \text{ - линейный код} $$
# $$ a(x)\text{ - информационный полином причем, } \deg(a(x)) < 51; $$

# %% [markdown]
# $$\text{Пусть } a(x) = x ^ 8 + x ^ 5 + x ^ 3 + x ^ 2 + 1; $$

# %% [markdown]
# $$\text{Систематическое кодирование : } V(x) = a(x) \cdot x ^ r + (a(x)\cdot x ^ r)\mod (g(x)) $$
# $$ x ^ r = x ^ {12}, a(x) \cdot x ^ r = (x ^ 8 + x ^ 5 + x ^ 3 + x ^ 2 + 1) \cdot x ^ {12} = x ^ {20} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12}, (a(x)\cdot x ^ r)\mod (g(x)) = x ^ {11} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + x + 1 \implies $$
# $$ V(x) = x ^ {20} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12} + x ^ {11} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + x + 1;$$
# $$ U(x) = V(x) + e(x); $$
# $$ H = \begin{bmatrix}
#    1 & \alpha & \alpha ^ {2} & \dots & \alpha ^ {50} \\
#    1 & \alpha ^ {2} & \alpha ^ {4} & \vdots & \alpha ^ {100} \\
#    1 & \alpha ^ {3} & \alpha ^ {9} & \vdots & \alpha ^ {150} \\
#    1 & \alpha ^ {4} & \alpha ^ {8} & \dots & \alpha ^ {200}
# \end{bmatrix} \implies
# \text{Синдром ошибки: }
# S\left( U(x)=\begin{pmatrix}
#    S_1 \\
#    S_2 \\
#    S_3 \\
#    S_4
# \end{pmatrix}=\begin{pmatrix}
#    U(\alpha) = e(\alpha) \\
#    U(\alpha ^ 2) = e(\alpha ^ 2) \\
#    U(\alpha ^ 3) = e(\alpha ^ 3) \\
#    U(\alpha ^ 4) = e(\alpha ^ 4)
# \end{pmatrix}\right) $$
# $$\text{Ошибок нет:} $$
# $$ S_1 = U(\alpha) = \alpha ^ {20} + \alpha ^ {17} + \alpha ^ {15} + \alpha ^ {14} + \alpha ^ {12} + \alpha ^ {11} + \alpha ^ {9} + \alpha ^ {8} + \alpha ^ {7} + \alpha ^ {5} + \alpha ^ {4} + \alpha + 1 = (\alpha ^ {2} + \alpha + 1) + (\alpha ^ {5} + \alpha ^ {2} + \alpha) + (\alpha ^ {5} + \alpha ^ {2}) + (\alpha ^ {4} + \alpha) + (\alpha ^ {5} + \alpha ^ {3} + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {3} + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {2} + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {2} + \alpha + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {2} + \alpha) + (\alpha ^ {5} + \alpha ^ {4} + \alpha + 1) = 0 $$
# $$ S_2 = U(\alpha ^ {2}) = \alpha ^ {40} + \alpha ^ {34} + \alpha ^ {30} + \alpha ^ {28} + \alpha ^ {24} + \alpha ^ {22} + \alpha ^ {18} + \alpha ^ {16} + \alpha ^ {14} + \alpha ^ {10} + \alpha ^ {8} + \alpha ^ {2} + 1 = 0 $$
# $$ S_3 = U(\alpha ^ {3}) = \alpha ^ {60} + \alpha ^ {51} + \alpha ^ {45} + \alpha ^ {42} + \alpha ^ {36} + \alpha ^ {33} + \alpha ^ {27} + \alpha ^ {24} + \alpha ^ {21} + \alpha ^ {15} + \alpha ^ {12} + \alpha ^ {3} + 1 = 0 $$
# $$ S_4 = U(\alpha ^ {4}) = \alpha ^ {17} + \alpha ^ {5} + \alpha ^ {60} + \alpha ^ {56} + \alpha ^ {48} + \alpha ^ {44} + \alpha ^ {36} + \alpha ^ {32} + \alpha ^ {28} + \alpha ^ {20} + \alpha ^ {16} + \alpha ^ {4} + 1 = 0 $$
# $$ \text{\large{Допустим одну ошибку: }} $$
# $$ U(x) = \underline{0} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12} + x ^ {11} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + x + 1; $$
# $$ S_1 = \alpha ^ {17} + \alpha ^ {15} + \alpha ^ {14} + \alpha ^ {12} + \alpha ^ {11} + \alpha ^ {9} + \alpha ^ {8} + \alpha ^ {7} + \alpha ^ {5} + \alpha ^ {4} + \alpha + 1 = \alpha ^ {2} + \alpha + 1 = \alpha ^ {20} $$
# $$ S_2 = \alpha ^ {34} + \alpha ^ {30} + \alpha ^ {28} + \alpha ^ {24} + \alpha ^ {22} + \alpha ^ {18} + \alpha ^ {16} + \alpha ^ {14} + \alpha ^ {10} + \alpha ^ {8} + \alpha ^ {2} + 1 = \alpha ^ {4} + \alpha ^ {2} + 1 = \alpha ^ {40} $$
# $$ S_3 = \alpha ^ {51} + \alpha ^ {45} + \alpha ^ {42} + \alpha ^ {36} + \alpha ^ {33} + \alpha ^ {27} + \alpha ^ {24} + \alpha ^ {21} + \alpha ^ {15} + \alpha ^ {12} + \alpha ^ {3} + 1 = \alpha ^ {5} + \alpha ^ {4} = \alpha ^ {60} $$
# $$ S_4 = \alpha ^ {5} + \alpha ^ {60} + \alpha ^ {56} + \alpha ^ {48} + \alpha ^ {44} + \alpha ^ {36} + \alpha ^ {32} + \alpha ^ {28} + \alpha ^ {20} + \alpha ^ {16} + \alpha ^ {4} + 1 = \alpha ^ {5} + \alpha ^ {2} + \alpha = \alpha ^ {17}  $$
# $$ \underline{\text{Алгоритм Эвклида: }} $$
# $$ \text{Начальные значения: }a_0 = x ^ {2t} = x ^ 4, a_1 = b = S(x) = \displaystyle\sum_{j = 1} ^ {2t} S _ j x ^ {j - 1} = \alpha ^ {17} x ^ {3} + \alpha ^ {60} x ^ {2} + \alpha ^ {40} x + \alpha ^ {20}, y_0 = 0, y_1 = 1 $$
# $$ \text{Формулы: } a_i = a_{i+1}q_{i+1} + a_{i+2}, y_{i+2} = y_i - y_{i+1} \cdot q_{i+1} $$
# $$ \text{Найдем }y_i\text{ , где }\deg(a_i)\leqslant t-1 = 1 $$
# $$ \text{При }j = 0\text{ : } $$
# $$ a_0 = a_1 \cdot q_1 + a_2 \implies a_0 = x ^ {4}, a_1 = \alpha ^ {17} x ^ {3} + \alpha ^ {60} x ^ {2} + \alpha ^ {40} x + \alpha ^ {20}, a_2 = \alpha ^ {46} $$
# $$ y_2 = y_0 - y_1 \cdot q_1 = 0 - 1 \cdot (\alpha ^ {46} x + \alpha ^ {26}) = \alpha ^ {46}x + \alpha ^ {26} $$
# $$ \deg(a_2) \leqslant t - 1 \implies i = 2 \implies \text{т.к. }\sigma(0) = 1\text{, то } \sigma(x) = \chi \omega(x) = \alpha ^ {37} (\alpha ^ {46}x + \alpha ^ {26}) = \alpha ^ {20}x + 1 $$
# $$ X_i = \alpha ^ {j_1} \text{, где }j_1\text{ - место ошибки} $$
# $$ \text{Корни: } X_1^{-1} = \alpha ^ {43} \implies X_1 = (\alpha ^ {43}) ^ {-1} = \alpha ^ {20} \implies j_1 = 20 \implies \text{ошибка в 20м месте} $$

# %% [markdown]
# $$\text{Пример кода БЧХ}$$

# %% [markdown]
# $$\alpha ^ {b}, \alpha ^ {b + 1}, ..., \alpha ^ {b + d - 2}; d = 2t + 1; GF(2 ^ 6) \implies q = 2, m = 6; b = 1, t = 2 \implies d = 2 \cdot 2 + 1 = 5 \implies b + d - 2 = 1 + 5 - 2 = 4 \implies \alpha, \alpha ^ 2, ..., \alpha ^ 4 \implies $$
# $$ g(x) = (x ^ 6 + x ^ 4 + x ^ 3 + x + 1) \cdot (x ^ 6 + x ^ 5 + x ^ 4 + x ^ 2 + 1) = x ^ {12} + x ^ {11} + x ^ 8 + x ^ 5 + x ^ 2 + x + 1;$$
# $$ n = q ^ m - 1 = 2 ^ 6 - 1 = 63, r = \deg(g(x)) = n - k = 12 \implies k = 63 - 12 = 51 \implies (63,51) \text{ - линейный код} $$
# $$ a(x)\text{ - информационный полином причем, } \deg(a(x)) < 51; $$

# %% [markdown]
# $$\text{Пусть } a(x) = x ^ 8 + x ^ 5 + x ^ 3 + x ^ 2 + 1; $$

# %% [markdown]
# $$\text{Систематическое кодирование : } V(x) = a(x) \cdot x ^ r + (a(x)\cdot x ^ r)\mod (g(x)) $$
# $$ x ^ r = x ^ {12}, a(x) \cdot x ^ r = (x ^ 8 + x ^ 5 + x ^ 3 + x ^ 2 + 1) \cdot x ^ {12} = x ^ {20} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12}, (a(x)\cdot x ^ r)\mod (g(x)) = x ^ {11} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + x + 1 \implies $$
# $$ V(x) = x ^ {20} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12} + x ^ {11} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + x + 1;$$
# $$ U(x) = V(x) + e(x); $$
# $$ H = \begin{bmatrix}
#    1 & \alpha & \alpha ^ {2} & \dots & \alpha ^ {50} \\
#    1 & \alpha ^ {2} & \alpha ^ {4} & \vdots & \alpha ^ {100} \\
#    1 & \alpha ^ {3} & \alpha ^ {9} & \vdots & \alpha ^ {150} \\
#    1 & \alpha ^ {4} & \alpha ^ {8} & \dots & \alpha ^ {200}
# \end{bmatrix} \implies
# \text{Синдром ошибки: }
# S\left( U(x)=\begin{pmatrix}
#    S_1 \\
#    S_2 \\
#    S_3 \\
#    S_4
# \end{pmatrix}=\begin{pmatrix}
#    U(\alpha) = e(\alpha) \\
#    U(\alpha ^ 2) = e(\alpha ^ 2) \\
#    U(\alpha ^ 3) = e(\alpha ^ 3) \\
#    U(\alpha ^ 4) = e(\alpha ^ 4)
# \end{pmatrix}\right) $$
# $$\text{Ошибок нет:} $$
# $$ S_1 = U(\alpha) = \alpha ^ {20} + \alpha ^ {17} + \alpha ^ {15} + \alpha ^ {14} + \alpha ^ {12} + \alpha ^ {11} + \alpha ^ {9} + \alpha ^ {8} + \alpha ^ {7} + \alpha ^ {5} + \alpha ^ {4} + \alpha + 1 = $$
# $$ = (\alpha ^ {2} + \alpha + 1) + (\alpha ^ {5} + \alpha ^ {2} + \alpha) + (\alpha ^ {5} + \alpha ^ {2}) + (\alpha ^ {4} + \alpha) + (\alpha ^ {5} + \alpha ^ {3} + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {3} + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {2} + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {2} + \alpha + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {2} + \alpha) + (\alpha ^ {5} + \alpha ^ {4} + \alpha + 1) = 0 $$
# $$ S_2 = U(\alpha ^ {2}) = \alpha ^ {40} + \alpha ^ {34} + \alpha ^ {30} + \alpha ^ {28} + \alpha ^ {24} + \alpha ^ {22} + \alpha ^ {18} + \alpha ^ {16} + \alpha ^ {14} + \alpha ^ {10} + \alpha ^ {8} + \alpha ^ {2} + 1 = 0 $$
# $$ S_3 = U(\alpha ^ {3}) = \alpha ^ {60} + \alpha ^ {51} + \alpha ^ {45} + \alpha ^ {42} + \alpha ^ {36} + \alpha ^ {33} + \alpha ^ {27} + \alpha ^ {24} + \alpha ^ {21} + \alpha ^ {15} + \alpha ^ {12} + \alpha ^ {3} + 1 = 0 $$
# $$ S_4 = U(\alpha ^ {4}) = \alpha ^ {17} + \alpha ^ {5} + \alpha ^ {60} + \alpha ^ {56} + \alpha ^ {48} + \alpha ^ {44} + \alpha ^ {36} + \alpha ^ {32} + \alpha ^ {28} + \alpha ^ {20} + \alpha ^ {16} + \alpha ^ {4} + 1 = 0 $$
# $$ \large{\text{Допустим одну ошибку: }} $$
# $$ U(x) = \underline{0} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12} + x ^ {11} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + x + 1; $$
# $$ S_1 = \alpha ^ {17} + \alpha ^ {15} + \alpha ^ {14} + \alpha ^ {12} + \alpha ^ {11} + \alpha ^ {9} + \alpha ^ {8} + \alpha ^ {7} + \alpha ^ {5} + \alpha ^ {4} + \alpha + 1 = \alpha ^ {2} + \alpha + 1 = \alpha ^ {20} $$
# $$ S_2 = \alpha ^ {34} + \alpha ^ {30} + \alpha ^ {28} + \alpha ^ {24} + \alpha ^ {22} + \alpha ^ {18} + \alpha ^ {16} + \alpha ^ {14} + \alpha ^ {10} + \alpha ^ {8} + \alpha ^ {2} + 1 = \alpha ^ {4} + \alpha ^ {2} + 1 = \alpha ^ {40} $$
# $$ S_3 = \alpha ^ {51} + \alpha ^ {45} + \alpha ^ {42} + \alpha ^ {36} + \alpha ^ {33} + \alpha ^ {27} + \alpha ^ {24} + \alpha ^ {21} + \alpha ^ {15} + \alpha ^ {12} + \alpha ^ {3} + 1 = \alpha ^ {5} + \alpha ^ {4} = \alpha ^ {60} $$
# $$ S_4 = \alpha ^ {5} + \alpha ^ {60} + \alpha ^ {56} + \alpha ^ {48} + \alpha ^ {44} + \alpha ^ {36} + \alpha ^ {32} + \alpha ^ {28} + \alpha ^ {20} + \alpha ^ {16} + \alpha ^ {4} + 1 = \alpha ^ {5} + \alpha ^ {2} + \alpha = \alpha ^ {17}  $$
# $$ \underline{\text{Алгоритм Эвклида: }} $$
# $$ \text{Начальные значения: }a_0 = x ^ {2t} = x ^ 4, a_1 = b = S(x) = \displaystyle\sum_{j = 1} ^ {2t} S _ j x ^ {j - 1} = \alpha ^ {17} x ^ {3} + \alpha ^ {60} x ^ {2} + \alpha ^ {40} x + \alpha ^ {20}, y_0 = 0, y_1 = 1 $$
# $$ \text{Формулы: } a_i = a_{i+1}q_{i+1} + a_{i+2}, y_{i+2} = y_i - y_{i+1} \cdot q_{i+1} $$
# $$ \text{Найдем }y_i\text{ , где }\deg(a_i)\leqslant t-1 = 1 $$
# $$ \text{При }j = 0\text{ : } $$
# $$ a_0 = a_1 \cdot q_1 + a_2 \implies a_0 = x ^ {4}, a_1 = \alpha ^ {17} x ^ {3} + \alpha ^ {60} x ^ {2} + \alpha ^ {40} x + \alpha ^ {20}, a_2 = \alpha ^ {46} $$
# $$ y_2 = y_0 - y_1 \cdot q_1 = 0 - 1 \cdot (\alpha ^ {46} x + \alpha ^ {26}) = \alpha ^ {46}x + \alpha ^ {26} $$
# $$ \deg(a_2) \leqslant t - 1 \implies i = 2 \implies \text{т.к. }\delta(0) = 1\text{, то } \delta(x) = X \omega(x) = \alpha ^ {37} (\alpha ^ {46}x + \alpha ^ {26}) = \alpha ^ {20}x + 1 $$
# $$ X_i = \alpha ^ {j_1} \text{, где }j_1\text{ - место ошибки} $$
# $$ \text{Корни: } X_1^{-1} = \alpha ^ {43} \implies X_1 = (\alpha ^ {43}) ^ {-1} = \alpha ^ {20} \implies j_1 = 20 \implies \text{ошибка в 20м месте} $$

# %% [markdown]
# $$ \underline{\text{Алгоритм Берлекэмпа-Месси: }} $$
# $$ \text{Начальные условия: } r = 0, L = 0, \delta(x) = 1, B(x) = 1; $$
# $$  r = r + 1 = 0 + 1 = 1 $$
# $$ \Delta_1 = \displaystyle\sum_{j = 0} ^ {L = 0} \delta_j S_{r - j} = \delta_0 S_{1 - 0} = \alpha ^ {20}; $$
# $$ \Delta_1 \neq 0 \implies T(x) = \delta(x) - \Delta_1 x B(x) = 1 - \alpha ^ {20} \cdot x \cdot 1 = \alpha ^ {20} x + 1; $$
# $$ 2 \cdot 0 \leqslant 1 - 1 $$
# $$ 0 \leqslant 0 \implies B(x) = \Delta ^ {-1} _ 1 \delta(x) = (\alpha ^ {20}) ^ {-1} \cdot 1 = \alpha ^ {43} $$
# $$ \delta(x) = T(x) = \alpha ^ {20} x + 1 $$
# $$ L = r - L = 1 - 0 = 1 $$
# $$ r \neq N \implies $$
# $$ r = r + 1 = 2 $$
# $$ \Delta_2 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{2 - 0} + \delta_1 S_{2 - 1} = \alpha ^ {40} + \alpha ^ {20} \cdot \alpha ^ {20} = 0; $$
# $$ \Delta_2 = 0 \implies B(x) = x \cdot 1 = x; $$
# $$ r \neq N \implies $$
# $$ r = r + 1 = 3; $$
# $$ \Delta_3 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{3} + \delta_1 S_{2} = 1 \cdot \alpha ^ {60} + \alpha ^ {20} \cdot \alpha ^ {40} = 0; $$
# $$ \Delta_3 = 0 \implies B(x) = x \cdot x = x ^ {2}; $$
# $$ r \neq N \implies $$
# $$ r = r + 1 = 4; $$
# $$ \Delta_4 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{4} + \delta_1 S_{3} = 1 \cdot \alpha ^ {17} + \alpha ^ {20} \cdot \alpha ^ {60} = 0; $$
# $$ \Delta_4 = 0 \implies B(x) = x \cdot x ^ {2} = x ^ {3}; $$
# $$ r = N \implies \delta(x) = \alpha ^ {20} x + 1; L = 1; \deg(\delta(x)) = L; $$

# %% [markdown]
# $$ \large{\text{Допустим две ошибки: }} $$
# $$ U(x) = x ^ {20} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12} + x ^ {11} + \underline{x ^ {10}} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + \underline{x ^ {2}} + x + 1; $$
# $$ S_j^q = S_{jq} $$
# $$ S_{1} = \alpha ^ {9}, S_{2} = (\alpha ^ {9}) ^ 2 = \alpha ^ {18}, S_{3} = \alpha ^ {47}, S_{4} = \alpha ^ {36}; $$
# $$ \underline{\text{Алгоритм Эвклида: }} $$
# $$ \text{Начальные значения: }a_0 = x ^ {2t} = x ^ 4, a_1 = b = S(x) = \displaystyle\sum_{j = 1} ^ {2t} S _ j x ^ {j - 1} = \alpha ^ {36} x ^ {3} + \alpha ^ {27} x ^ {2} + \alpha ^ {18} x + \alpha ^ {9}, y_0 = 0, y_1 = 1 $$
# $$ \text{Формулы: } a_i = a_{i+1}q_{i+1} + a_{i+2}, y_{i+2} = y_i - y_{i+1} \cdot q_{i+1} $$
# $$ \text{Найдем }y_i\text{ , где }\deg(a_i)\leqslant t-1 = 1 $$
# $$ \text{При }j = 0\text{ : } $$
# $$ a_0 = a_1 \cdot q_1 + a_2 \implies a_0 = x ^ {4}, a_1 = \alpha ^ {36} x ^ {3} + \alpha ^ {47} x ^ {2} + \alpha ^ {18} x + \alpha ^ {9}, a_2 = \alpha ^ {33} x ^ {2} + \alpha ^ {30} x + \alpha ^ {47}, q_1 = \alpha ^ {27} x + \alpha ^ {38} $$
# $$ y_2 = y_0 - y_1 \cdot q_1 = 0 - 1 \cdot (\alpha ^ {27} x + \alpha ^ {38}) = \alpha ^ {27} x + \alpha ^ {38} $$
# $$ \deg(a_0) = 4; \deg(a_1) = 3; \deg(a_2) = 2; $$
# $$ a_1 = a_2 \cdot q_2 + a_3 \implies a_2 = \alpha ^ {33} x ^ {2} + \alpha ^ {30} x + \alpha ^ {47}, a_3 = 1 + \alpha ^ {9} = \alpha ^ {27} , q_2 = \alpha ^ {3} x + \alpha ^ {16} $$
# $$ \deg(a_3) \leqslant t - 1 $$
# $$ 0 \leqslant 1 \text{ - да}$$
# $$ y_3 = y_1 - y_2 \cdot q_2 = 1 + (\alpha ^ {27}x + \alpha ^ {38})(\alpha ^ {3}x + \alpha ^ {16}) = 1 + (\alpha ^ {30} x ^ 2 + \alpha ^ {41} x + \alpha ^ {43} x + \alpha ^ {54}) = \alpha ^ {30} x ^ 2 + \alpha ^ {27} x + \alpha ^ {18} $$
# $$ \delta(x) = \alpha ^ {45}(\alpha ^ {30} x ^ 2 + \alpha ^ {27} x + \alpha ^ {18}) = \alpha ^ {12} x ^ 2 + \alpha ^ {9} x + 1; $$
# $$ X _ 1 ^ {-1} = \alpha ^ {53}; X _ 2 ^ {-1} = \alpha ^ {61};$$
# $$ X _ 1 = \alpha ^ {10}; X _ 2 = \alpha ^ {2};$$
# $$ \underline{\text{Алгоритм Берлекэмпа-Месси: }} $$
# $$ \text{Начальные условия: } r = 0, L = 0, \delta(x) = 1, B(x) = 1; $$
# $$  r = r + 1 = 0 + 1 = 1 $$
# $$ \Delta_1 = \displaystyle\sum_{j = 0} ^ {L = 0} \delta_j S_{r - j} = \delta_0 S_{1}  = \alpha ^ {9}; $$
# $$ \Delta_1 = \alpha ^ {9} \neq 0 \implies T(x) = \delta(x) - \Delta_1 x B(x) = 1 - \alpha ^ {9} \cdot x \cdot 1 = \alpha ^ {9} x + 1; $$
# $$ 2 \cdot 0 \leqslant 1 - 1 $$
# $$ 0 \leqslant 0 \text{ - да} $$
# $$ \implies B(x) = \Delta ^ {-1} _ 1 \delta(x) = (\alpha ^ {9}) ^ {-1} \cdot 1 = \alpha ^ {54} $$
# $$ \delta(x) = T(x) = \alpha ^ {9} x + 1 $$
# $$ L = r - L = 1 - 0 = 1 $$
# $$ r \neq N \implies $$
# $$ r = r + 1 = 2 $$
# $$ \Delta_2 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{2 - 0} + \delta_1 S_{2 - 1} = \alpha ^ {18} + \alpha ^ {9} \cdot \alpha ^ {9} = 0; $$
# $$ \Delta_2 = 0 \implies B(x) = x \cdot B(x) = \alpha ^ {54} x; $$
# $$ r \neq N \implies $$
# $$ r = r + 1 = 3; $$
# $$ \Delta_3 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{3} + \delta_1 S_{2} = \alpha ^ {47} + \alpha ^ {9} \cdot \alpha ^ {18} = \alpha ^ {21}; $$
# $$ \Delta_3 = \alpha ^ {21} \neq 0 $$
# $$ T(x) = \delta(x) - \Delta_3 x B(x) = \alpha ^ {9} x + 1 + \alpha ^ {21} \cdot x \cdot \alpha ^ {54} \cdot x = \alpha ^ {12} x ^ 2 + \alpha ^ {9} x + 1 $$
# $$ 2 \cdot 1 \leqslant 3 - 1 $$
# $$ 2 \leqslant 2 \implies B(x) = \Delta_3^{-1}\delta(x) = (\alpha ^ {21}) ^ {-1} \cdot \alpha ^ {9}x + 1 = \alpha ^ {51}x + \alpha ^ {42}; $$
# $$ \delta(x) = T(x) = \alpha ^ {12} x ^ {2} + \alpha ^ {9} x + 1; $$
# $$ L = r - L = 3 - 1 = 2; $$
# $$ 3 = 4 \text{ - нет} $$
# $$ r = 3 + 1 = 4; $$
# $$ \Delta_4 = \displaystyle\sum_{j = 0} ^ {L = 2} \delta_j S_{r - j} = \delta_0 S_{4} + \delta_1 S_{3} + \delta_2 S_{2} = \alpha ^ {36} + \alpha ^ {9} \cdot \alpha ^ {47} + \alpha ^ {12} \cdot \alpha ^ {18} = 0; $$
# $$ \Delta_4 = 0; B(x) = x \cdot B(x) = \alpha ^ {51} x ^ 2 + \alpha ^ {42} x $$
# $$ 4 = 4 \text{ - да} $$
# $$ \delta(x) = \alpha ^ {12} x ^ 2 + \alpha ^ {9} x + 1; L = 2; \deg(\delta(x)) = L; $$
# $$ \delta(\alpha ^ {53}) = 0; \delta(\alpha ^ {61}) = 0;  $$
# $$ X _ 1 = \alpha ^ {10}; X _ 2 = \alpha ^ {2};$$

# %% [markdown]
# $$\text{Пример кода Рида-Соломона}$$
# $$\alpha ^ {b}, \alpha ^ {b + 1}, ..., \alpha ^ {b + d - 2}; GF(2 ^ 6); \boxed{d = n - k + 1} $$
# $$ b = 1, t = 2 \implies d = 2t + 1 = 5 \implies b + d - 2 = 1 + 5 - 2 = 4; $$
# $$ \alpha, \alpha ^ 2, \alpha ^ 3, \alpha ^ 4 \implies  $$
# $$ g(x) = (x - \alpha)(x - \alpha ^ 2)(x - \alpha ^ 3)(x - \alpha ^ 4) = (x ^ 2 + (\alpha + \alpha ^ 2)x + \alpha ^ 3)(x ^ 2 + (\alpha ^ 3 + \alpha ^ 4)x + \alpha ^ 7) = $$
# $$ = (x ^ 2 + \alpha ^ {57}x + \alpha ^ 3)(x ^ 2 + \alpha ^ {59}x + \alpha ^ 7) = x ^ 4 + \alpha ^ {43}x ^ 3 + \alpha ^ {9}x ^ 2 + \alpha ^ {48}x + \alpha ^ {10} $$
# $$ r = \deg (g(x)) = n - k = 4 \implies k = n - r = 63 - 4 = 59; $$
# $$ \text{Проверим МДР: } d = n - k + 1 = 63 - 59 + 1 =5 $$
# $$ \text {Степень информационных полиномов : } \deg (a(x)) < 59\text{, а коэффициенты }\in \mathbb{F}_{2 ^ 6} $$
# $$ \text{Пусть пришли биты информации: } $$
# $$
# \begin{array}{c:c:c:c:c:c:c:c:c:c}
#    00 \dots 0 & 010111 & 000000 & 000000 & 101010 & 000000 & 010110 & 011011 & 000000 & 101011 \\
#    \dots & \alpha ^ {18} & 0 & 0 & \alpha ^ {41} & 0 & \alpha ^ {54} & \alpha ^ {6} & 0 & \alpha ^ {24}
# \end{array} \implies a(x) = \alpha ^ {18} x ^ {8} + \alpha ^ {41} x ^ {5} + \alpha ^ {54} x ^ {3} + \alpha ^ {6} x ^ {2} + \alpha ^ {24};
# $$
# $$ \text{Несистематическое кодирование: } V = (a(1), a(\alpha), ..., a(\alpha ^ {64 - 2})) $$
# $$ \text{Систематическое кодирование: } V(x) = a(x) \cdot x ^ r + (a(x) \cdot x ^ r) \mod (g(x)) $$
# $$ V(x) = \alpha ^ {18} x ^ {12} + \alpha ^ {41} x ^ {9} + \alpha ^ {54} x ^ {7} + \alpha ^ {6} x ^ {6} + \alpha ^ {24} x ^ {4} + \alpha ^ {47} x ^ {3} + \alpha ^ {56} x ^ {2} + \alpha ^ {40} x + \alpha ^ {17} $$
# $$ \text{Без ошибок} $$
# $$ S_1 = \alpha ^ {18 + 12} + \alpha ^ {41 + 9} + \alpha ^ {54 + 7} + \alpha ^ {6 + 6} + \alpha ^ {24 + 4} + \alpha ^ {47 + 3} + \alpha ^ {56 + 2} + \alpha ^ {41} + \alpha ^ {17} = 0 $$
# $$ S_2 = 0 $$
# $$ S_3 = \alpha ^ {18} \cdot (\alpha ^ {3}) ^ {12} + \alpha ^ {41} \cdot (\alpha ^ {3}) ^ {9} + \alpha ^ {54} \cdot (\alpha ^ {3}) ^ {7} + \alpha ^ {6} \cdot (\alpha ^ {3}) ^ {6} + \alpha ^ {24} \cdot (\alpha ^ {3}) ^ {4} + \alpha ^ {47} \cdot (\alpha ^ {3}) ^ {3} + \alpha ^ {56} \cdot (\alpha ^ {3}) ^ {2} + \alpha ^ {40} \cdot (\alpha ^ {3}) + \alpha ^ {17} = 0  $$
# $$ S_4 = 0 \implies \text{ ошибок нет } $$
# $$ U(x) = V(x) + e(x); $$
# $$ \large{\text{Допустим одну ошибку: }} $$
# $$ U(x) = \alpha ^ {18} x ^ {12} + \underline{\alpha ^ {43} x ^ {10}} + \alpha ^ {41} x ^ {9} + \alpha ^ {54} x ^ {7} + \alpha ^ {6} x ^ {6} + \alpha ^ {24} x ^ {4} + \alpha ^ {47} x ^ {3} + \alpha ^ {56} x ^ {2} + \alpha ^ {40} x + \alpha ^ {17}; $$
# $$ S_1 = \alpha ^ {43} \cdot \alpha ^ {10} = \alpha ^ {53}; $$
# $$ S_2 = \alpha ^ {43} \cdot (\alpha ^ {2}) ^ {10} = 1 $$
# $$ S_3 = \alpha ^ {43} \cdot (\alpha ^ {3}) ^ {10} = \alpha ^ {43} \cdot \alpha ^ {30} = \alpha ^ {10}; $$
# $$ S_4 = \alpha ^ {43} \cdot (\alpha ^ {4}) ^ {10} = \alpha ^ {43} \cdot \alpha ^ {40} = \alpha ^ {20}; $$
# $$ \underline{\text{Алгоритм Эвклида: }} $$
# $$ \text{Начальные значения: }a_0 = x ^ {2t} = x ^ 4, a_1 = b = S(x) = \displaystyle\sum_{j = 1} ^ {2t} S _ j x ^ {j - 1} = \alpha ^ {20} x ^ {3} + \alpha ^ {10} x ^ {2} + x + \alpha ^ {53}, y_0 = 0, y_1 = 1 $$
# $$ \text{Формулы: } a_i = a_{i+1}q_{i+1} + a_{i+2}, y_{i+2} = y_i - y_{i+1} \cdot q_{i+1} $$
# $$ \text{Найдем }y_i\text{ , где }\deg(a_i)\leqslant t-1 = 1 $$
# $$ \text{При }j = 0\text{ : } $$
# $$ a_0 = a_1 \cdot q_1 + a_2 \implies q_1 = (\alpha ^ {4} + \alpha ^ {3} + \alpha ^ {2} + \alpha)x + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {3} + \alpha ^ {2} + \alpha + 1);$$
# $$ a_2 = \alpha ^ {5} + \alpha ^ {4} + \alpha ^ {3} = \alpha ^ {23}; $$
# $$ \deg(a_2) \leqslant t - 1 \implies i = 2 $$
# $$ 0 \leqslant 1 \text{ - да } $$
# $$ y_2 = y_0 - y_1 \cdot q_1 = 0 - 1 (\alpha ^ {43}x + \alpha ^ {33}) = \alpha ^ {43}x + \alpha ^ {33}; $$
# $$ \text{Т.к } \delta(0) = 1\text{, то } \delta(x) = \alpha ^ {30} (\alpha ^ {43}x + \alpha ^ {33}) = \alpha ^ {10}x + 1 $$
# $$ X_1^{-1} = \alpha ^ {53} \implies X_1 = \alpha ^ {10} \text{ - ошибка на 10м месте}$$
# $$ \Omega(x) = (-1) ^ i \alpha ^ {30} \cdot a_i = (-1) ^ 2 \cdot \alpha ^ {30} \cdot \alpha ^ {23} = \alpha ^ {53}; $$
# $$ \delta'(x) = \alpha ^ {10} $$
# $$ Y_1 = - \frac{\alpha ^ {53}}{\alpha ^ {10}} = \alpha ^ {53} \cdot (\alpha ^ {10}) ^ {-1} = \alpha ^ {53} \cdot \alpha ^ {53} = \alpha ^ {43} \implies e(x) = \alpha ^ {43} x ^ {10}; $$
# $$ \underline{\text{Алгоритм Берлекэмпа-Месси: }} $$
# $$ \text{Начальные условия: } r = 0, L = 0, \delta(x) = 1, B(x) = 1; $$
# $$  r = r + 1 = 0 + 1 = 1 $$
# $$ \Delta_1 = \displaystyle\sum_{j = 0} ^ {L = 0} \delta_j S_{r - j} = \delta_0 S_{1}  = \alpha ^ {53}; $$
# $$ \Delta_1 = \alpha ^ {53} \neq 0 \implies T(x) = \delta(x) + \Delta_1 x B(x) = 1 + \alpha ^ {53} \cdot x = \alpha ^ {53} x + 1; $$
# $$ 2 \cdot 0 \leqslant 1 - 1 \text { - да } $$
# $$ B(x) = (\Delta_1)^{-1} \cdot \delta(x) = (\alpha ^ {53})^{-1} \cdot 1 = \alpha ^ {10}; $$
# $$ \delta(x)= \alpha ^ {53}x + 1 $$
# $$ L = r - L = 1 - 0 = 1; $$
# $$ r \neq 2t $$
# $$ r = 2 $$
# $$ \Delta_2 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{2 - 0} + \delta_1 S_{2 - 1} = 1 \cdot 1 + \alpha ^ {53} \cdot \alpha ^ {53} = 1 + \alpha ^ {43} = \alpha ^ {37}; $$
# $$ \Delta_2 \neq 0 \implies T(x) = \delta(x) + \Delta_2 x B(x) = \alpha ^ {53} x + 1 + \alpha ^ {37} \cdot x \cdot \alpha ^ {10} = \alpha ^ {10}x + 1; $$
# $$ 2 \cdot 1 \leqslant 2 - 1 $$
# $$ 2 \leqslant 1 \text{ - нет} $$
# $$ \delta(x)= \alpha ^ {10}x + 1 $$
# $$ B(x) = x \cdot B(x) = \alpha ^ {10} x $$
# $$ r \neq 2t $$
# $$ r = 3 $$
# $$ \Delta_3 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{3} + \delta_1 S_{2} = 1 \cdot \alpha ^ {10} + \alpha ^ {10} \cdot 1 = 0; $$
# $$ \Delta_3 = 0 $$
# $$ B(x) = x \cdot B(x) = \alpha ^ {10} x ^ 2 $$
# $$ r = 4 $$
# $$ \Delta_4 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{4} + \delta_1 S_{3} = 1 \cdot \alpha ^ {20} + \alpha ^ {10} \cdot \alpha ^ {10} = 0; $$
# $$ \Delta_4 = 0 $$
# $$ B(x) = x \cdot B(x) = \alpha ^ {10} x ^ 3 $$
# $$ r = 2t \implies \delta(x) = \alpha ^ {10}x + 1 \text{ , }L = 1;  $$

# %% [markdown]
# $$ \large{\text{Допустим две ошибки: }} $$
# $$ U(x) = \alpha ^ {18} x ^ {12} + \alpha ^ {41} x ^ {9} + \underline{\alpha ^ {12} x ^ {8}} + \alpha ^ {54} x ^ {7} + \alpha ^ {6} x ^ {6} + \underline{\alpha ^ {38} x ^ {5}} + \alpha ^ {24} x ^ {4} + \alpha ^ {47} x ^ {3} + \alpha ^ {56} x ^ {2} + \alpha ^ {40} x + \alpha ^ {17}; $$
# $$ S_1 = \alpha ^ {12} \cdot \alpha ^ {8} + \alpha ^ {38} \cdot \alpha ^ {5} = \alpha ^ {31}; $$
# $$ S_2 = \alpha ^ {12} \cdot (\alpha ^ {2}) ^ {8} + \alpha ^ {38} \cdot (\alpha ^ {2}) ^ {5} = \alpha ^ {22} $$
# $$ S_3 = \alpha ^ {12} \cdot (\alpha ^ {3}) ^ {8} + \alpha ^ {38} \cdot (\alpha ^ {3}) ^ {5} = \alpha ^ {12}; $$
# $$ S_4 = \alpha ^ {12} \cdot (\alpha ^ {4}) ^ {8} + \alpha ^ {38} \cdot (\alpha ^ {4}) ^ {5} = \alpha ^ {60}; $$
# $$ \underline{\text{Алгоритм Эвклида: }} $$
# $$ \text{Начальные значения: }a_0 = x ^ {2t} = x ^ 4, a_1 = b = S(x) = \displaystyle\sum_{j = 0} ^ {2t} S _ j x ^ {j - 1} = \alpha ^ {31} + \alpha ^ {22} x + \alpha ^ {12} x ^ 2 + \alpha ^ {60} x ^ 3, y_0 = 0, y_1 = 1 $$
# $$ \text{При }j = 0\text{ : } $$
# $$ a_0 = a_1 \cdot q_1 + a_2 \implies q_1 = \alpha ^ {3}x + (\alpha ^ {4} + \alpha ^ {2} + \alpha + 1) = \alpha ^ {3}x + \alpha ^ {18}; a_2 = \alpha ^ {55} x ^ 2 + \alpha ^ {60} x + \alpha ^ {49} $$
# $$ \deg ( a_2 ) \leqslant t - 1 $$
# $$ 2 \leqslant 1 \text{ - нет } $$
# $$ y_2 = y_0 - y_1 \cdot q_1 = \alpha ^ {3} x + \alpha ^ {18};$$
# $$ \text{При }j = 1\text{ : } $$
# $$ a_1 = a_2 \cdot q_2 + a_3 \implies q_2 = \alpha ^ {5}x + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {2} + \alpha) = \alpha ^ {5}x + \alpha ^ {7}; a_3 = (\alpha ^ {4} + \alpha ^ {3} + \alpha)x + (\alpha ^ {4} + \alpha ^ {3} + \alpha) = \alpha ^ {26}x + \alpha ^ {26} $$
# $$ \deg ( a_3 ) \leqslant t - 1 $$
# $$ 1 \leqslant 1 \text{ - да } $$
# $$ y_3 = y_1 - y_2 \cdot q_2 = 1 + (\alpha ^ {3}x + \alpha ^ {18})(\alpha ^ {5}x + \alpha ^ {7}) = \alpha ^ {8} x ^ {2} + \alpha ^ {13} x + \alpha ^ {58}; $$
# $$ \chi = \alpha ^ {5}; \delta(x) = \alpha ^ {5} (\alpha ^ {8} x ^ {2} + \alpha ^ {13} x + \alpha ^ {58}) = \alpha ^ {13} x ^ {2} + \alpha ^ {18} x + 1; $$
# $$ X_1 ^ {-1} = \alpha ^ {55}, X_2 ^ {-1} = \alpha ^ {58}; $$
# $$ X_1 = \alpha ^ {8}, X_2 = \alpha ^ {5}; $$
# $$ \Omega(x) = (-1) ^ {i} \chi a_{i} = \alpha ^ {5} \cdot (\alpha ^ {26}x + \alpha ^ {26}) = \alpha ^ {31}x + \alpha ^ {31}; \delta^{\prime} = \alpha ^ {18}; $$
# $$ Y_{i} = - \frac{\Omega(X_i^{-1})}{\delta^{\prime}(X_i^{-1})}; Y_1 = \frac{ \alpha ^ {31} \cdot \alpha ^ {55} + \alpha ^ {31}}{\alpha ^ {18}} = (\alpha ^ {18}) ^ {-1} \cdot (\alpha ^ {31 + 55} + \alpha ^ {31}) = \alpha ^ {12}; $$
# $$ Y_2 = \alpha ^ {45} \cdot (\alpha ^ {31} \cdot \alpha ^ {58} + \alpha ^ {31}) = \alpha ^ {38} \implies e(x) = \alpha ^ {12} x ^ {8} + \alpha ^ {38} x ^ {5}; $$
# $$ \underline{\text{Алгоритм Берлекэмпа-Месси: }} $$
# $$ \text{Начальные условия: } r = 0, L = 0, \delta(x) = 1, B(x) = 1; $$
# $$ r = r + 1 = 0 + 1 = 1 $$
# $$ \Delta_1 = \displaystyle\sum_{j = 0} ^ {L = 0} \delta_j S_{r - j} = \alpha ^ {31}; $$
# $$ \Delta_1 = \alpha ^ {31} \neq 0 \implies T(x) = \delta(x) - \Delta_r x B(x) = 1 + \alpha ^ {31} \cdot x \cdot 1 = \alpha ^ {31} x + 1; $$
# $$ 2 \cdot 0 \leqslant 1 - 1 \text { - да } $$
# $$ B(x) = (\Delta_r)^{-1} \cdot \delta(x) = \alpha ^ {32}; $$
# $$ \delta(x)= \alpha ^ {31}x + 1 $$
# $$ L = r - L = 1 - 0 = 1; $$
# $$ r = 2 $$
# $$ \Delta_2 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_0 S_{r - j} = \delta_0 S_2 + \delta_1 S_1 = 1 \cdot S_2 + \alpha ^ {31} \cdot S_1 = \alpha ^ {22} + \alpha ^ {31} \cdot \alpha ^ {31} = \alpha ^ {10} \neq 0 ; $$
# $$ T(x) = \delta(x) + \Delta_2 \cdot x \cdot B(x) = (\alpha ^ {31} x + 1) + \alpha ^ {10} \cdot x \cdot \alpha ^ {32} = \alpha ^ {54}x + 1; $$
# $$ 2 \cdot 1 \leqslant 2 - 1 \text { - нет } $$
# $$ \delta(x)= \alpha ^ {54}x + 1; $$
# $$ B(x) = x \cdot B(x) = \alpha ^ {32}x; $$
# $$ r = 3 $$
# $$ \Delta_3 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_3 + \delta_1 S_2 = 1 \cdot \alpha ^ {12} + \alpha ^ {54} \cdot \alpha ^ {22} = \alpha ^ {5} \neq 0; $$
# $$ T(x) = \delta(x) + \Delta_3 \cdot x \cdot B(x) = (\alpha ^ {54} x + 1) + \alpha ^ {5} \cdot x \cdot \alpha ^ {32} \cdot x = \alpha ^ {37}x ^ {2} + \alpha ^ {54}x + 1; $$
# $$ 2 \cdot 1 \leqslant 3 - 1 \text { - да } $$
# $$ B(x) = (\alpha ^ {5}) ^ {-1} \cdot (\alpha ^ {54}x + 1) = \alpha ^ {58}(\alpha ^ {54}x + 1) = \alpha ^ {49}x + \alpha ^ {58}; $$
# $$ \delta(x) = \alpha ^ {37} x ^ {2} + \alpha ^ {54} x + 1; $$
# $$ L = r - L = 3 - 1 = 2; $$
# $$ r = 4 $$
# $$ \Delta_4 = \displaystyle\sum_{j = 0} ^ {L = 2} \delta_j S_{r - j} = \delta_0 S_4 + \delta_1 S_3 + \delta_2 S_2 = S_4 + \alpha ^ {54} S_3 + \alpha ^ {37} S_2 = \alpha ^ {60} + \alpha ^ {54} \cdot \alpha ^ {12} \neq \alpha ^ {37} \cdot \alpha ^ {22} = \alpha ^ {5}; $$
# $$ T(x) = \delta(x) + \Delta_5 \cdot x \cdot B(x) = (\alpha ^ {37} x ^ 2 + \alpha ^ {54} x + 1) + \alpha ^ {5} x \cdot (\alpha ^ {49} x + \alpha ^ {58}) = \alpha ^ {13} x ^ {2} + \alpha ^ {9} x + 1; $$
# $$ 2 \cdot 2 \leqslant 4 - 1 \text { - нет } $$
# $$ \delta(x) = \alpha ^ {13} x ^ 2 + \alpha ^ {18} x + 1; L = 2; $$

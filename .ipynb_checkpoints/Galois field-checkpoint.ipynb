# %% [markdown]
# $$
# \text{Конечное поле (поле Галуа) }GF(2 ^ 6)
# \text{, которое опишем через } \mathbb{F}_2[x]/(x^6+x^4+x^3+x+1) \text{ по изоморфизму, где } x^6+x^4+x^3+x+1 \text{-неприводимый полином над }\mathbb{F}_2[x]
# $$
#
#
# $$
# \begin{array}{c:c:c}
# \text{Элемент поля }GF(2 ^ 6)
# &
# \text{Элемент поля }\mathbb{F}_2[x]/(x^6+x^4+x^3+x+1)
# &
# \text{Битовое представление} \\ \hline
# \alpha ^ \infty
# &
# 0
# &
# 000000 \\ \hdashline
# \alpha ^ 0
# &
# 1
# &
# 000001 \\ \hdashline
# \alpha
# &
# x
# &
# 000010 \\ \hdashline
# \alpha ^ 2
# &
# x ^ 2
# &
# 000100 \\ \hdashline
# \alpha ^ 3
# &
# x ^ 3
# &
# 001000 \\ \hdashline
# \alpha ^ 4
# &
# x ^ 4
# &
# 010000 \\ \hdashline
# \alpha ^ 5
# &
# x ^ 5
# &
# 100000 \\ \hdashline
# \alpha ^ 6 = \alpha ^ 4 + \alpha ^ 3 + \alpha + 1
# &
# x ^ 4 + x ^ 3 + x + 1
# &
# 011011 \\ \hdashline
# \alpha ^ 7 = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 2 + \alpha
# &
# x ^ 5 + x ^ 4 + x ^ 2 + x
# &
# 110110 \\ \hdashline
# \alpha ^ 8 = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 5 + x ^ 4 + x ^ 2 + x + 1
# &
# 110111 \\ \hdashline
# \alpha ^ 9 = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 2 + 1
# &
# x ^ 5 + x ^ 4 + x ^ 2 + 1
# &
# 110101 \\ \hdashline
# \alpha ^ {10} = \alpha ^ 5 + \alpha ^ 4 + 1
# &
# x ^ 5 + x ^ 4 + 1
# &
# 110001 \\ \hdashline
# \alpha ^ {11} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + 1
# &
# x ^ 5 + x ^ 4 + x ^ 3 + 1
# &
# 111001 \\ \hdashline
# \alpha ^ {12} = \alpha ^ 5 + \alpha ^ 3 + 1
# &
# x ^ 5 + x ^ 3 + 1
# &
# 101001 \\ \hdashline
# \alpha ^ {13} = \alpha ^ 3 + 1
# &
# x ^ 3 + 1
# &
# 001001 \\ \hdashline
# \alpha ^ {14} = \alpha ^ 4 + \alpha
# &
# x ^ 4 + x
# &
# 010010 \\ \hdashline
# \alpha ^ {15} = \alpha ^ 5 + \alpha ^ 2
# &
# x ^ 5 + x ^ 2
# &
# 100100 \\ \hdashline
# \alpha ^ {16} = \alpha ^ 4 + \alpha + 1
# &
# x ^ 4 + x + 1
# &
# 010011 \\ \hdashline
# \alpha ^ {17} = \alpha ^ 5 + \alpha ^ 2 + \alpha
# &
# x ^ 5 + x ^ 2 + x
# &
# 100110 \\ \hdashline
# \alpha ^ {18} = \alpha ^ 4 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 4 + x ^ 2 + x + 1
# &
# 010111 \\ \hdashline
# \alpha ^ {19} = \alpha ^ 5 + \alpha ^ 3 + \alpha ^ 2 + \alpha
# &
# x ^ 5 + x ^ 3 + x ^ 2 + x
# &
# 101110 \\ \hdashline
# \alpha ^ {20} = \alpha ^ 2 + \alpha + 1
# &
# x ^ 2 + x + 1
# &
# 000111 \\ \hdashline
# \alpha ^ {21} = \alpha ^ 3 + \alpha ^ 2 + \alpha
# &
# x ^ 3 + x ^ 2 + x
# &
# 001110 \\ \hdashline
# \alpha ^ {22} = \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2
# &
# x ^ 4 + x ^ 3 + x ^ 2
# &
# 011100 \\ \hdashline
# \alpha ^ {23} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3
# &
# x ^ 5 + x ^ 4 + x ^ 3
# &
# 111000 \\ \hdashline
# \alpha ^ {24} = \alpha ^ 5 + \alpha ^ 3 + \alpha + 1
# &
# x ^ 5 + x ^ 3 + x + 1
# &
# 101011 \\ \hdashline
# \alpha ^ {25} = \alpha ^ 3 + \alpha ^ 2 + 1
# &
# x ^ 3 + x ^ 2 + 1
# &
# 001101 \\ \hdashline
# \alpha ^ {26} = \alpha ^ 4 + \alpha ^ 3 + \alpha
# &
# x ^ 4 + x ^ 3 + x
# &
# 011010 \\ \hdashline
# \alpha ^ {27} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 2
# &
# x ^ 5 + x ^ 4 + x ^ 2
# &
# 110100 \\ \hdashline
# \alpha ^ {28} = \alpha ^ 5 + \alpha ^ 4 + \alpha + 1
# &
# x ^ 5 + x ^ 4 + x + 1
# &
# 110011 \\ \hdashline
# \alpha ^ {29} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + 1
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x ^ 2 + 1
# &
# 111101 \\ \hdashline
# \alpha ^ {30} = \alpha ^ 5 + 1
# &
# x ^ 5 + 1
# &
# 100001 \\ \hdashline
# \alpha ^ {31} = \alpha ^ 4 + \alpha ^ 3 + 1
# &
# x ^ 4 + x ^ 3 + 1
# &
# 011001 \\ \hdashline
# \alpha ^ {32} = \alpha ^ 5 + \alpha ^ 4 + \alpha
# &
# x ^ 5 + x ^ 4 + x
# &
# 110010 \\ \hdashline
# \alpha ^ {33} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x ^ 2 + x + 1
# &
# 111111 \\ \hdashline
# \alpha ^ {34} = \alpha ^ 5 + \alpha ^ 2 + 1
# &
# x ^ 5 + x ^ 2 + 1
# &
# 100101 \\ \hdashline
# \alpha ^ {35} = \alpha ^ 4 + 1
# &
# x ^ 4 + 1
# &
# 010001 \\ \hdashline
# \alpha ^ {36} = \alpha ^ 5 + \alpha
# &
# x ^ 5 + x
# &
# 100010 \\ \hdashline
# \alpha ^ {37} = \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 4 + x ^ 3 + x ^ 2 + x + 1
# &
# 011111 \\ \hdashline
# \alpha ^ {38} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + \alpha
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x ^ 2 + x
# &
# 111110 \\ \hdashline
# \alpha ^ {39} = \alpha ^ 5 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 5 + x ^ 2 + x + 1
# &
# 100111 \\ \hdashline
# \alpha ^ {40} = \alpha ^ 4 + \alpha ^ 2 + 1
# &
# x ^ 4 + x ^ 2 + 1
# &
# 010101
# \end {array}
# $$
#
# $$
# \begin{array}{c:c:c}
# \text{Элемент поля }GF(2 ^ 6)
# &
# \text{Элемент поля }\mathbb{F}_2[x]/(x^6+x^4+x^3+x+1)
# &
# \text{Битовое представление} \\ \hline
# \alpha ^ {41} = \alpha ^ 5 + \alpha ^ 3 + \alpha
# &
# x ^ 5 + x ^ 3 + x
# &
# 101010 \\ \hdashline
# \alpha ^ {42} = \alpha ^ 3 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 3 + x ^ 2 + x + 1
# &
# 001111 \\ \hdashline
# \alpha ^ {43} = \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + \alpha
# &
# x ^ 4 + x ^ 3 + x ^ 2 + x
# &
# 011110 \\ \hdashline
# \alpha ^ {44} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x ^ 2
# &
# 111100 \\ \hdashline
# \alpha ^ {45} = \alpha ^ 5 + \alpha + 1
# &
# x ^ 5 + x + 1
# &
# 100011 \\ \hdashline
# \alpha ^ {46} = \alpha ^ 4 + \alpha ^ 3 + \alpha ^ 2 + 1
# &
# x ^ 4 + x ^ 3 + x ^ 2 + 1
# &
# 011101 \\ \hdashline
# \alpha ^ {47} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x
# &
# 111010 \\ \hdashline
# \alpha ^ {48} = \alpha ^ 5 + \alpha ^ 3 + \alpha ^ 2 + \alpha + 1
# &
# x ^ 5 + x ^ 3 + x ^ 2 + x + 1
# &
# 101111 \\ \hdashline
# \alpha ^ {49} = \alpha ^ 2 + 1
# &
# x ^ 2 + 1
# &
# 000101 \\ \hdashline
# \alpha ^ {50} = \alpha ^ 3 + \alpha
# &
# x ^ 3 + x
# &
# 001010 \\ \hdashline
# \alpha ^ {51} = \alpha ^ 4 + \alpha ^ 2
# &
# x ^ 4 + x ^ 2
# &
# 010100 \\ \hdashline
# \alpha ^ {52} = \alpha ^ 5 + \alpha ^ 3
# &
# x ^ 5 + x ^ 3
# &
# 101000 \\ \hdashline
# \alpha ^ {53} = \alpha ^ 3 + \alpha + 1
# &
# x ^ 3 + x + 1
# &
# 001011 \\ \hdashline
# \alpha ^ {54} = \alpha ^ 4 + \alpha ^ 2 + \alpha
# &
# x ^ 4 + x ^ 2 + x
# &
# 010110 \\ \hdashline
# \alpha ^ {55} = \alpha ^ 5 + \alpha ^ 3 + \alpha ^ 2
# &
# x ^ 5 + x ^ 3 + x ^ 2
# &
# 101100 \\ \hdashline
# \alpha ^ {56} = \alpha + 1
# &
# x + 1
# &
# 000011 \\ \hdashline
# \alpha ^ {57} = \alpha ^ 2 + \alpha
# &
# x ^ 2 + x
# &
# 000110 \\ \hdashline
# \alpha ^ {58} = \alpha ^ 3 + \alpha ^ 2
# &
# x ^ 3 + x ^ 2
# &
# 001100 \\ \hdashline
# \alpha ^ {59} = \alpha ^ 4 + \alpha ^ 3
# &
# x ^ 4 + x ^ 3
# &
# 011000 \\ \hdashline
# \alpha ^ {60} = \alpha ^ 5 + \alpha ^ 4
# &
# x ^ 5 + x ^ 4
# &
# 110000 \\ \hdashline
# \alpha ^ {61} = \alpha ^ 5 + \alpha ^ 4 + \alpha ^ 3 + \alpha + 1
# &
# x ^ 5 + x ^ 4 + x ^ 3 + x + 1
# &
# 111011 \\ \hdashline
# \alpha ^ {62} = \alpha ^ 5 + \alpha ^ 3 + \alpha ^ 2 + 1
# &
# x ^ 5 + x ^ 3 + x ^ 2 + 1
# &
# 101101
# \end {array}
# $$
#
#
# $$\text{Минимальные многочлены}$$
#
# $$
# m_0(x) = x + 1 = (x + \alpha ^ {0});
# $$
# $$
# m_1(x) = x ^ 6 + x ^ 4 + x ^ 3 + x + 1 = (x + \alpha)(x + \alpha ^ {2})(x + \alpha ^ {4})(x + \alpha ^ {8})(x + \alpha ^ {16})(x + \alpha ^ {32});
# $$
# $$
# m_2(x) = x ^ 6 + x ^ 5 + x ^ 4 + x ^ 2 + 1 = (x + \alpha ^ {3})(x + \alpha ^ {6})(x + \alpha ^ {12})(x + \alpha ^ {24})(x + \alpha ^ {48})(x + \alpha ^ {33});
# $$
# $$
# m_3(x) = x ^ 6 + x + 1 = (x + \alpha ^ {5})(x + \alpha ^ {10})(x + \alpha ^ {20})(x + \alpha ^ {40})(x + \alpha ^ {17})(x + \alpha ^ {34});
# $$
# $$
# m_4(x) = x ^ 6 + x ^ 3 + 1 = (x + \alpha ^ {7})(x + \alpha ^ {14})(x + \alpha ^ {28})(x + \alpha ^ {56})(x + \alpha ^ {49})(x + \alpha ^ {35});
# $$
# $$
# m_5(x) = x ^ 3 + x + 1 = (x + \alpha ^ {9})(x + \alpha ^ {18})(x + \alpha ^ {36});
# $$
# $$
# m_6(x) = x ^ 6 + x ^ 5 + x ^ 2 + x + 1 = (x + \alpha ^ {11})(x + \alpha ^ {22})(x + \alpha ^ {44})(x + \alpha ^ {25})(x + \alpha ^ {50})(x + \alpha ^ {37});
# $$
# $$
# m_7(x) = x ^ 6 + x ^ 5 + x ^ 4 + x + 1 = (x + \alpha ^ {13})(x + \alpha ^ {26})(x + \alpha ^ {52})(x + \alpha ^ {41})(x + \alpha ^ {19})(x + \alpha ^ {38});
# $$
# $$
# m_8(x) = x ^ 6 + x ^ 4 + x ^ 2 + x + 1 = (x + \alpha ^ {15})(x + \alpha ^ {30})(x + \alpha ^ {60})(x + \alpha ^ {57})(x + \alpha ^ {51})(x + \alpha ^ {39});
# $$
# $$
# m_9(x) = x ^ 2 + x + 1 = (x + \alpha ^ {21})(x + \alpha ^ {42});
# $$
# $$
# m_{10}(x) = x ^ 6 + x ^ 5 + 1 = (x + \alpha ^ {23})(x + \alpha ^ {46})(x + \alpha ^ {29})(x + \alpha ^ {58})(x + \alpha ^ {53})(x + \alpha ^ {43});
# $$
# $$
# m_{11}(x) = x ^ 3 + x ^ 2 + 1 = (x + \alpha ^ {27})(x + \alpha ^ {54})(x + \alpha ^ {45});
# $$
# $$
# m_{12}(x) = x ^ 6 + x ^ 5 + x ^ 3 + x ^ 2 + 1 = (x + \alpha ^ {31})(x + \alpha ^ {62})(x + \alpha ^ {61})(x + \alpha ^ {59})(x + \alpha ^ {55})(x + \alpha ^ {47});
# $$

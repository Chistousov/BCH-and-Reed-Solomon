# %% [markdown]
# $$\text{Пример кода БЧХ в узком смысле}$$
# $$\text{Корни порождающего многочлена } g(x) \text{ определены как } \alpha ^ {b}, \alpha ^ {b + 1}, ..., \alpha ^ {b + d - 2}$$
# $$\text{Реализуем код, который исправляет 2 ошибки }(t=2) \text{, в конечном поле }GF(2 ^ 6) \text{. При этом } b = 1 $$
# $$\text{Для поля } GF(2 ^ 6) \text{ имеем } p = 2, m = 6 $$
# $$\text{Кодовое расстояние задается как } d = 2t + 1 = 2 \cdot 2 + 1 = 5$$
# $$\text{Т.к. } b + d - 2 = 1 + 5 - 2 = 4 \text{, то корни порождающего многочлена } \alpha, \alpha ^ 2, \alpha ^ 3, \alpha ^ 4 \implies \text{минимальные многочлены: } m_1(x), m_2(x)$$
# $$\text{Найдем порождающий многочлен:} $$
# $$ g(x) = m_1(x) \cdot m_2(x) = (x ^ 6 + x ^ 4 + x ^ 3 + x + 1) \cdot (x ^ 6 + x ^ 5 + x ^ 4 + x ^ 2 + 1) = x ^ {12} + x ^ {11} + x ^ 8 + x ^ 5 + x ^ 2 + x + 1 $$
# $$\text{Т.к. БЧХ в узком смысле, то } n = p ^ m - 1 = 2 ^ 6 - 1 = 63, r = \deg(g(x)) = n - k = 12 \implies k = 63 - 12 = 51 \implies (63,51) \text{ - линейный код} $$
# $$\implies \deg(a(x)) < 51\text{, где } a(x)\text{ - информационный полином и } deg(V(x)) < 63 \text{, где } V(x)\text{ - закодированное для передачи сообщение(полином)}$$
# $$\text{Пусть необходимо передать следующую информацию: } \overbrace{000...000100101101}^{\text{51 - бит}} \implies a(x) = x ^ 8 + x ^ 5 + x ^ 3 + x ^ 2 + 1 $$
# $$\text{Воспользуемся систематическим кодированием для закодирования информационного сообщения: } $$
# $$ V(x) = a(x) \cdot x ^ r + (a(x)\cdot x ^ r)\mod (g(x)) $$
# $$ x ^ r = x ^ {12}, a(x) \cdot x ^ r = (x ^ 8 + x ^ 5 + x ^ 3 + x ^ 2 + 1) \cdot x ^ {12} = x ^ {20} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12}, (a(x)\cdot x ^ r)\mod (g(x)) =  $$
# $$ x ^ {11} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + x + 1 \implies $$
# $$\text{Имеем закодированное сообщение: } V(x) = x ^ {20} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12} + x ^ {11} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + x + 1$$
# $$\text{Переданное по каналу связи закодированное сообщение имеет вид: } U(x) = V(x) + e(x)\text{, где } e(x) \text{ - вектор ошибки;} $$
# $$\text{Проверочная матрица: } H = \begin{bmatrix}
#    1 & \alpha & \alpha ^ {2} & \dots & \alpha ^ {50} \\
#    1 & \alpha ^ {2} & \alpha ^ {4} & \vdots & \alpha ^ {100} \\
#    1 & \alpha ^ {3} & \alpha ^ {9} & \vdots & \alpha ^ {150} \\
#    1 & \alpha ^ {4} & \alpha ^ {8} & \dots & \alpha ^ {200}
# \end{bmatrix} \implies
# \text{Синдром ошибки: }
# S(U(x))=\begin{pmatrix}
#    S_1 \\
#    S_2 \\
#    S_3 \\
#    S_4
# \end{pmatrix}=\begin{pmatrix}
#    U(\alpha) = e(\alpha) \\
#    U(\alpha ^ 2) = e(\alpha ^ 2) \\
#    U(\alpha ^ 3) = e(\alpha ^ 3) \\
#    U(\alpha ^ 4) = e(\alpha ^ 4)
# \end{pmatrix} $$
# $$\text{Допустим принятое сообщение не имеет ошибок }(U(x) = V(x) + 0 = V(x)) \implies \text{ синдром ошибки: } $$
# $$ S_1 = U(\alpha) = \alpha ^ {20} + \alpha ^ {17} + \alpha ^ {15} + \alpha ^ {14} + \alpha ^ {12} + \alpha ^ {11} + \alpha ^ {9} + \alpha ^ {8} + \alpha ^ {7} + \alpha ^ {5} + \alpha ^ {4} + \alpha + 1 = $$
# $$ = (\alpha ^ {2} + \alpha + 1) + (\alpha ^ {5} + \alpha ^ {2} + \alpha) + (\alpha ^ {5} + \alpha ^ {2}) + (\alpha ^ {4} + \alpha) + (\alpha ^ {5} + \alpha ^ {3} + 1) + $$
# $$ + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {3} + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {2} + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {2} + \alpha + 1) + (\alpha ^ {5} + \alpha ^ {4} + \alpha ^ {2} + \alpha) + $$
# $$ + (\alpha ^ {5} + \alpha ^ {4} + \alpha + 1) = 0 $$
# $$ S_2 = U(\alpha ^ {2}) = \alpha ^ {40} + \alpha ^ {34} + \alpha ^ {30} + \alpha ^ {28} + \alpha ^ {24} + \alpha ^ {22} + \alpha ^ {18} + \alpha ^ {16} + \alpha ^ {14} + \alpha ^ {10} + \alpha ^ {8} + \alpha ^ {2} + 1 = 0 $$
# $$ S_3 = U(\alpha ^ {3}) = \alpha ^ {60} + \alpha ^ {51} + \alpha ^ {45} + \alpha ^ {42} + \alpha ^ {36} + \alpha ^ {33} + \alpha ^ {27} + \alpha ^ {24} + \alpha ^ {21} + \alpha ^ {15} + \alpha ^ {12} + \alpha ^ {3} + 1 = 0 $$
# $$ S_4 = U(\alpha ^ {4}) = \alpha ^ {17} + \alpha ^ {5} + \alpha ^ {60} + \alpha ^ {56} + \alpha ^ {48} + \alpha ^ {44} + \alpha ^ {36} + \alpha ^ {32} + \alpha ^ {28} + \alpha ^ {20} + \alpha ^ {16} + \alpha ^ {4} + 1 = 0 $$
# $$ \large{\text{Допустим одну ошибку: }} (U(x) = \underline{0} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12} + x ^ {11} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + x + 1) $$
# $$ S_1 = U(\alpha) = \alpha ^ {17} + \alpha ^ {15} + \alpha ^ {14} + \alpha ^ {12} + \alpha ^ {11} + \alpha ^ {9} + \alpha ^ {8} + \alpha ^ {7} + \alpha ^ {5} + \alpha ^ {4} + \alpha + 1 = \alpha ^ {2} + \alpha + 1 = \alpha ^ {20} $$
# $$ S_2 = U(\alpha ^ {2}) = \alpha ^ {34} + \alpha ^ {30} + \alpha ^ {28} + \alpha ^ {24} + \alpha ^ {22} + \alpha ^ {18} + \alpha ^ {16} + \alpha ^ {14} + \alpha ^ {10} + \alpha ^ {8} + \alpha ^ {2} + 1 = \alpha ^ {4} + \alpha ^ {2} + 1 = \alpha ^ {40} $$
# $$ S_3 = U(\alpha ^ {3}) = \alpha ^ {51} + \alpha ^ {45} + \alpha ^ {42} + \alpha ^ {36} + \alpha ^ {33} + \alpha ^ {27} + \alpha ^ {24} + \alpha ^ {21} + \alpha ^ {15} + \alpha ^ {12} + \alpha ^ {3} + 1 = \alpha ^ {5} + \alpha ^ {4} = \alpha ^ {60} $$
# $$ S_4 = U(\alpha ^ {4}) = \alpha ^ {5} + \alpha ^ {60} + \alpha ^ {56} + \alpha ^ {48} + \alpha ^ {44} + \alpha ^ {36} + \alpha ^ {32} + \alpha ^ {28} + \alpha ^ {20} + \alpha ^ {16} + \alpha ^ {4} + 1 = \alpha ^ {5} + \alpha ^ {2} + \alpha = \alpha ^ {17}  $$
# $$ \underline{\text{Алгоритм Евклида: }} $$
# $$ \text{Начальные значения: }a_0 = x ^ {2t} = x ^ 4, a_1 = b = S(x) = \displaystyle\sum_{j = 1} ^ {2t} S _ j x ^ {j - 1} = \alpha ^ {17} x ^ {3} + \alpha ^ {60} x ^ {2} + \alpha ^ {40} x + \alpha ^ {20}, y_0 = 0, y_1 = 1 $$
# $$ \text{Формулы: } a_i = a_{i+1}q_{i+1} + a_{i+2}, y_{i+2} = y_i - y_{i+1} \cdot q_{i+1} $$
# $$ \text{Найдем }y_i\text{ , где }\deg(a_i)\leqslant t-1 = 1 $$
# $$ \text{При }i = 0\text{ : } $$
# $$ a_0 = a_1 \cdot q_1 + a_2 \implies a_0 = x ^ {4}, a_1 = \alpha ^ {17} x ^ {3} + \alpha ^ {60} x ^ {2} + \alpha ^ {40} x + \alpha ^ {20}, a_2 = \alpha ^ {46} $$
# $$ y_2 = y_0 - y_1 \cdot q_1 = 0 - 1 \cdot (\alpha ^ {46} x + \alpha ^ {26}) = \alpha ^ {46}x + \alpha ^ {26} $$
# $$ \deg(a_2) \leqslant t - 1 \implies i = 2 $$
# $$ \text{Найдем многочлен локаторов ошибок: } \delta(x) = \chi y_{i} = \chi y_{2} \text{ при условии, что } \delta(0) = 1\text { т.е подберем } \chi $$
# $$ \chi = \alpha ^ {37} \text{ т.к. } \alpha ^ {37} (\alpha ^ {46} \cdot 0 + \alpha ^ {26}) = 1  $$
# $$ \implies \delta(x) = \alpha ^ {37} (\alpha ^ {46} x + \alpha ^ {26}) = \alpha ^ {20}x + 1  $$
# $$ \text{Корни многочлена локаторов ошибок равны обратным величинам локаторов ошибок} $$
# $$ X_i = (\alpha ^ {j_1}) ^ {-1} \text{ - корень многочлена локаторов ошибок, а } j_i \text{ - место ошибки}$$
# $$ \text{Корень } X_1 = \alpha ^ {43} \implies \text{ локатор ошибок равен } (\alpha ^ {43}) ^ {-1} = \alpha ^ {20} \implies j_1 = 20 \implies \text{ошибка в 20м месте} $$
# $$ \text{Т.к. значение коэффициентов вектора ошибок равняется 1, то получаем следующий вектор ошибок } e(x) = x ^ {20} $$
# $$ \implies \text{ правильная комбинация определяется как } V(x) = U(x) + e(x); $$
# $$ \underline{\text{Алгоритм Берлекэмпа-Месси: }} $$
# $$ \text{Начальные условия: } r = 0, L = 0, \delta(x) = 1, B(x) = 1; $$
# $$ \text{Итерация } r = r + 1 = 0 + 1 = 1 $$
# $$ \Delta_1 = \displaystyle\sum_{j = 0} ^ {L = 0} \delta_j S_{r - j} = \delta_0 S_{1 - 0} = \alpha ^ {20}; $$
# $$ \Delta_1 \neq 0 \implies T(x) = \delta(x) - \Delta_1 x B(x) = 1 - \alpha ^ {20} \cdot x \cdot 1 = \alpha ^ {20} x + 1; $$
# $$ 2 \cdot 0 \leqslant 1 - 1 $$
# $$ 0 \leqslant 0 \implies B(x) = \Delta ^ {-1} _ 1 \delta(x) = (\alpha ^ {20}) ^ {-1} \cdot 1 = \alpha ^ {43} $$
# $$ \delta(x) = T(x) = \alpha ^ {20} x + 1 $$
# $$ L = r - L = 1 - 0 = 1 $$
# $$ r \neq 2t \implies $$
# $$ \text{Итерация } r = r + 1 = 2 $$
# $$ \Delta_2 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{2 - 0} + \delta_1 S_{2 - 1} = \alpha ^ {40} + \alpha ^ {20} \cdot \alpha ^ {20} = 0; $$
# $$ \Delta_2 = 0 \implies B(x) = x \cdot 1 = x; $$
# $$ r \neq 2t \implies $$
# $$ \text{Итерация } r = r + 1 = 3; $$
# $$ \Delta_3 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{3} + \delta_1 S_{2} = 1 \cdot \alpha ^ {60} + \alpha ^ {20} \cdot \alpha ^ {40} = 0; $$
# $$ \Delta_3 = 0 \implies B(x) = x \cdot x = x ^ {2}; $$
# $$ r \neq 2t \implies $$
# $$ \text{Итерация } r = r + 1 = 4; $$
# $$ \Delta_4 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{4} + \delta_1 S_{3} = 1 \cdot \alpha ^ {17} + \alpha ^ {20} \cdot \alpha ^ {60} = 0; $$
# $$ \Delta_4 = 0 \implies B(x) = x \cdot x ^ {2} = x ^ {3}; $$
# $$ r = 2t \implies \text{Многочлен локаторов ошибок равен } \delta(x) = \alpha ^ {20} x + 1; \text{ Причем } L = 1; \deg(\delta(x)) = L; $$
# $$ \text{Вектор ошибки находится аналогично выше} $$
# $$ \large{\text{Допустим две ошибки: }} $$
# $$ U(x) = x ^ {20} + x ^ {17} + x ^ {15} + x ^ {14} + x ^ {12} + x ^ {11} + \underline{x ^ {10}} + x ^ {9} + x ^ {8} + x ^ {7} + x ^ {5} + x ^ {4} + \underline{x ^ {2}} + x + 1; $$
# $$ S_j^q = S_{jq} $$
# $$ S_{1} = \alpha ^ {9}, S_{2} = (\alpha ^ {9}) ^ 2 = \alpha ^ {18}, S_{3} = \alpha ^ {47}, S_{4} = \alpha ^ {36}; $$
# $$ \underline{\text{Алгоритм Евклида: }} $$
# $$ \text{Начальные значения: }a_0 = x ^ {2t} = x ^ 4, a_1 = b = S(x) = \displaystyle\sum_{j = 1} ^ {2t} S _ j x ^ {j - 1} = \alpha ^ {36} x ^ {3} + \alpha ^ {27} x ^ {2} + \alpha ^ {18} x + \alpha ^ {9}, y_0 = 0, y_1 = 1 $$
# $$ \text{Формулы: } a_i = a_{i+1}q_{i+1} + a_{i+2}, y_{i+2} = y_i - y_{i+1} \cdot q_{i+1} $$
# $$ \text{Найдем }y_i\text{ , где }\deg(a_i)\leqslant t-1 = 1 $$
# $$ \text{При }i = 0\text{ : } $$
# $$ a_0 = a_1 \cdot q_1 + a_2 \implies a_0 = x ^ {4}, a_1 = \alpha ^ {36} x ^ {3} + \alpha ^ {47} x ^ {2} + \alpha ^ {18} x + \alpha ^ {9}, a_2 = \alpha ^ {33} x ^ {2} + \alpha ^ {30} x + \alpha ^ {47}, q_1 = \alpha ^ {27} x + \alpha ^ {38} $$
# $$ y_2 = y_0 - y_1 \cdot q_1 = 0 - 1 \cdot (\alpha ^ {27} x + \alpha ^ {38}) = \alpha ^ {27} x + \alpha ^ {38} $$
# $$ \deg(a_0) = 4; \deg(a_1) = 3; \deg(a_2) = 2; $$
# $$ a_1 = a_2 \cdot q_2 + a_3 \implies a_2 = \alpha ^ {33} x ^ {2} + \alpha ^ {30} x + \alpha ^ {47}, a_3 = 1 + \alpha ^ {9} = \alpha ^ {27} , q_2 = \alpha ^ {3} x + \alpha ^ {16} $$
# $$ \deg(a_3) \leqslant t - 1 $$
# $$ 0 \leqslant 1 \text{ - да} \implies i = 3 $$
# $$ y_3 = y_1 - y_2 \cdot q_2 = 1 + (\alpha ^ {27}x + \alpha ^ {38})(\alpha ^ {3}x + \alpha ^ {16}) = 1 + (\alpha ^ {30} x ^ 2 + \alpha ^ {41} x + \alpha ^ {43} x + \alpha ^ {54}) = \alpha ^ {30} x ^ 2 + \alpha ^ {27} x + \alpha ^ {18} $$
# $$ \text{Найдем многочлен локаторов ошибок: } \delta(x) = \chi y_{i} = \chi y_{3} \text{ при условии, что } \delta(0) = 1\text { т.е подберем } \chi $$
# $$ \chi = \alpha ^ {45} \text{ т.к. } \alpha ^ {45} (\alpha ^ {30} \cdot 0 ^ 2 + \alpha ^ {27} \cdot 0 + \alpha ^ {18}) = 1  $$
# $$ \implies \delta(x) = \alpha ^ {45}(\alpha ^ {30} x ^ 2 + \alpha ^ {27} x + \alpha ^ {18}) = \alpha ^ {12} x ^ 2 + \alpha ^ {9} x + 1  $$
# $$ \text{Корни многочлена локаторов ошибок равны обратным величинам локаторов ошибок} $$
# $$ X_i = (\alpha ^ {j_1}) ^ {-1} \text{ - корень многочлена локаторов ошибок, а } j_i \text{ - место ошибки}$$
# $$ \text{Корень } X_1 = \alpha ^ {53} \implies \text{ локатор ошибок равен } (\alpha ^ {53}) ^ {-1} = \alpha ^ {10} \implies j_1 = 10 \implies \text{ошибка в 10 месте} $$
# $$ \text{Корень } X_2 = \alpha ^ {61} \implies \text{ локатор ошибок равен } (\alpha ^ {61}) ^ {-1} = \alpha ^ {2} \implies j_2 = 2 \implies \text{ошибка в 2 месте} $$
# $$ \text{Т.к. значение коэффициентов вектора ошибок равняется 1, то получаем следующий вектор ошибок } e(x) = x ^ {10} + x ^ {2} $$
# $$ \implies \text{ правильная комбинация определяется как } V(x) = U(x) + e(x); $$
# $$ \underline{\text{Алгоритм Берлекэмпа-Месси: }} $$
# $$ \text{Начальные условия: } r = 0, L = 0, \delta(x) = 1, B(x) = 1; $$
# $$ \text{Итерация } r = r + 1 = 0 + 1 = 1 $$
# $$ \Delta_1 = \displaystyle\sum_{j = 0} ^ {L = 0} \delta_j S_{r - j} = \delta_0 S_{1}  = \alpha ^ {9}; $$
# $$ \Delta_1 = \alpha ^ {9} \neq 0 \implies T(x) = \delta(x) - \Delta_1 x B(x) = 1 - \alpha ^ {9} \cdot x \cdot 1 = \alpha ^ {9} x + 1; $$
# $$ 2 \cdot 0 \leqslant 1 - 1 $$
# $$ 0 \leqslant 0 \text{ - да} $$
# $$ \implies B(x) = \Delta ^ {-1} _ 1 \delta(x) = (\alpha ^ {9}) ^ {-1} \cdot 1 = \alpha ^ {54} $$
# $$ \delta(x) = T(x) = \alpha ^ {9} x + 1 $$
# $$ L = r - L = 1 - 0 = 1 $$
# $$ r \neq N \implies $$
# $$ \text{Итерация } r = r + 1 = 2 $$
# $$ \Delta_2 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{2 - 0} + \delta_1 S_{2 - 1} = \alpha ^ {18} + \alpha ^ {9} \cdot \alpha ^ {9} = 0; $$
# $$ \Delta_2 = 0 \implies B(x) = x \cdot B(x) = \alpha ^ {54} x; $$
# $$ r \neq N \implies $$
# $$ \text{Итерация } r = r + 1 = 3; $$
# $$ \Delta_3 = \displaystyle\sum_{j = 0} ^ {L = 1} \delta_j S_{r - j} = \delta_0 S_{3} + \delta_1 S_{2} = \alpha ^ {47} + \alpha ^ {9} \cdot \alpha ^ {18} = \alpha ^ {21}; $$
# $$ \Delta_3 = \alpha ^ {21} \neq 0 $$
# $$ T(x) = \delta(x) - \Delta_3 x B(x) = \alpha ^ {9} x + 1 + \alpha ^ {21} \cdot x \cdot \alpha ^ {54} \cdot x = \alpha ^ {12} x ^ 2 + \alpha ^ {9} x + 1 $$
# $$ 2 \cdot 1 \leqslant 3 - 1 $$
# $$ 2 \leqslant 2 \implies B(x) = \Delta_3^{-1}\delta(x) = (\alpha ^ {21}) ^ {-1} \cdot \alpha ^ {9}x + 1 = \alpha ^ {51}x + \alpha ^ {42}; $$
# $$ \delta(x) = T(x) = \alpha ^ {12} x ^ {2} + \alpha ^ {9} x + 1; $$
# $$ L = r - L = 3 - 1 = 2; $$
# $$ 3 = 4 \text{ - нет} $$
# $$ \text{Итерация } r = 3 + 1 = 4; $$
# $$ \Delta_4 = \displaystyle\sum_{j = 0} ^ {L = 2} \delta_j S_{r - j} = \delta_0 S_{4} + \delta_1 S_{3} + \delta_2 S_{2} = \alpha ^ {36} + \alpha ^ {9} \cdot \alpha ^ {47} + \alpha ^ {12} \cdot \alpha ^ {18} = 0; $$
# $$ \Delta_4 = 0; B(x) = x \cdot B(x) = \alpha ^ {51} x ^ 2 + \alpha ^ {42} x $$
# $$ 4 = 4 \text{ - да} \implies \text{Многочлен локаторов ошибок равен } $$
# $$ \delta(x) = \alpha ^ {12} x ^ 2 + \alpha ^ {9} x + 1; \text{ Причем } L = 2; \deg(\delta(x)) = L; $$
# $$ \text{Вектор ошибки находится аналогично выше} $$
